# %%
#Rabbitmetrics YT - https://www.youtube.com/watch?v=rFQ5Kmkd4jc

import sys
print(sys.version)

# %%
#https://python.langchain.com/api_reference/community/utilities/langchain_community.utilities.requests.TextRequestsWrapper.html
from langchain.utilities import TextRequestsWrapper

# %%
requests = TextRequestsWrapper()

# %%
requests.get("https://jalcocert.github.io/JAlcocerT/using-langchain-with-pandas-df/")
# Out:
# '<!doctype html><html lang=en><head><meta charset=utf-8><meta name=viewport content="width=device-width,initial-scale=1"><meta name=robots content="index, follow"><link rel="icon shortcut" href=/JAlcocerT/favicon.ico sizes=32x32><link rel=icon href=/JAlcocerT/favicon.svg type=image/svg+xml><link rel=icon href=/JAlcocerT/favicon-dark.svg type=image/svg+xml media="(prefers-color-scheme: dark)"><link rel=icon href=/JAlcocerT/favicon-16x16.png type=image/png sizes=16x16><link rel=icon href=/JAlcocerT/favicon-32x32.png type=image/png sizes=32x32><link rel=apple-touch-icon href=/JAlcocerT/apple-touch-icon.png sizes=180x180><link fetchpriority=low href=/JAlcocerT/site.webmanifest rel=manifest><title>Using LangchAIn with pandas - Enhancing Trip Planner – JAlcocerT Blog</title><meta name=description content="How to use LangChain to chat with a Pandas DF."><meta property="og:title" content="Using LangchAIn with pandas - Enhancing Trip Planner"><meta property="og:description" content="How to us
# ...
